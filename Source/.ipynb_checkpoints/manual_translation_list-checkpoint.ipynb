# %% [markdown]
# #### 1. Importing Libraries

# %%
import json
import re

# %% [markdown]
# #### 2. Storing List of unique labels in a file

# %%
labelled_monuments = []
with open('../Data/Films/Films_Hindi_Wikipedia_Wikidata_EnLabelled/Films_Hindi_Wikipedia_Wikidata_EnLabelled.json', 'r') as f:
    labelled_monuments = json.load(f)

# %%
label_list = []
label_list_dict = {}
for key in labelled_monuments.keys():
    prop_value_dict = labelled_monuments[key]
    props = list(prop_value_dict.keys())
    label_list.extend(props)
    for prop in props:
        values = prop_value_dict[prop]
        for value in values:
            if type(value) == str:
                label_list.append(value)
            elif type(value) == dict:
                val_dict_keys = list(value.keys())
                label_list.extend(val_dict_keys)
                for val_dict_key in val_dict_keys:
                    if type(value[val_dict_key]) == str:
                        label_list.append(value[val_dict_key])

# %%
for label in label_list:
    label_list_dict[label] = ""

# %%
unique_label_list = list(label_list_dict.keys())

# %%
#Commented out because the list of labels is written into the file already, now its time to read it.
# with open('../Data/Films/film_labels.txt', 'w') as f:
#     for item in unique_label_list:
#         f.write("%s\n" % item)

# %% [markdown]
# #### 3. After manually translating the unique labels, storing them in a dictionary
# - Dictionary Mapping - English label as key  and its corresponding Hindi translation as its value

# %%
hi_unique_label_list = []
with open('../Data/Films/Manually_Translated_Labels/Films_Labels_Translated_hi.txt') as f:
    hi_unique_label_list = f.readlines()
hi_unique_label_list = [x.strip() for x in hi_unique_label_list]

# %%
for index in range(0,len(unique_label_list)):
    label_list_dict[unique_label_list[index]] = hi_unique_label_list[index]

# %% [markdown]
# #### 4. Reconstructing the Wikidata with Translated Hindi Labels for properties and values (Except for numbers, links)

# %%
hi_labelled_monuments = {}
for key in labelled_monuments.keys():
    monument_labelled_prop_val = {}
    
    prop_value_dict = labelled_monuments[key]
    props = list(prop_value_dict.keys())
    
    for prop in props:  
        
        labelled_values = []
        values = prop_value_dict[prop]
        
        for value in values:
            if type(value) == str:
                if value in label_list_dict.keys():
                    labelled_values.append(label_list_dict[value])
                else:
                    labelled_values.append(value)
            elif type(value) == dict:
                val_dict_keys = list(value.keys())
                hi_val_dict = {}
                for val_dict_key in val_dict_keys:
                    if value[val_dict_key] in label_list_dict:
                        hi_val_dict[label_list_dict[val_dict_key]] = label_list_dict[value[val_dict_key]]
                    else:
                        hi_val_dict[label_list_dict[val_dict_key]] = value[val_dict_key]
                labelled_values.append(hi_val_dict)
            else:
                labelled_values.append(str(value))
        
        monument_labelled_prop_val[label_list_dict[prop]] = labelled_values
    
    hi_labelled_monuments[key] = monument_labelled_prop_val

# %%
hi_labelled_monuments['Q24815']
# Out:
# {'निदेशक': ['ऑर्सन वेल्स'],
#  'आईएमडीबी आईडी': ['टीटी0033467'],
#  'कॉमन्स श्रेणी': ['नागरिक केन (1941 फिल्म)'],
#  'पटकथा लेखक': ['ऑर्सन वेल्स', 'हरमन जे Mankiewicz', 'जॉन हाउसमैन'],
#  'कास्ट मेंबर': ['ऑर्सन वेल्स',
#   'जोसेफ कॉटन',
#   'रूथ वारिक',
#   'एवरेट स्लोएन',
#   'विलियम ऑलएंड',
#   'पॉल स्टीवर्ट',
#   'जॉर्ज कूलूरिस',
#   'डोरोथी Comingore',
#   'एग्नेस मूरहेड',
#   'रे कोलिंस',
#   'फोर्टुनियो बोनानोवा',
#   'एर्स्कीन सैनफोर्ड',
#   'गस शिलिंग',
#   'एलन लाड',
#   'चार्ल्स बेनेट',
#   'गिनो कोराडो',
#   'हैरी शैनन',
#   'सन्नी बुप',
#   'वाल्टर सैंडे',
#   'फिलिप वान Zandt',
#   'रोलाण्ड विंटर्स'],
#  'फोटोग्राफी के निदेशक': ['ग्रेग टॉलैंड'],
#  'उत्पादन कंपनी': ['RKO पिक्चर्स'],
#  'उदाहरण': ['फिल्म'],
#  'फिल्मअफ़ीम आईडी': ['615891'],
#  'निर्माता': ['ऑर्सन वेल्स', 'जॉर्ज शेफर'],
#  'कथा स्थल': ['न्यूयॉर्क शहर', 'फ्लोरिडा'],
#  'जीएनडी आईडी': ['4208625-5'],
#  'आधिकारिक वेबसाइट': ['http://www2.warnerbros.com/citizenkane/'],
#  'फ्रीबेस आईडी': ['/m/01lsl'],
#  'छवि': ['सिटीजन केन पोस्टर, 1941 (स्टाइल बी, अशांतिफैलाई। - जेपीजी',
#   'सिटीजन केन पोस्टर, 1941 (स्टाइल ए. जेपीजी'],
#  'एलोसिन फिल्म आईडी': ['857'],
#  'सड़े टमाटर आईडी': ['मे/citizen_kane'],
#  'प्रकाशन तिथि': [{'समय': '+1941-05-01T00:00:00Z',
#    'समयक्षेत्र': 0,
#    'पहले': 0,
#    'बाद': 0,
#    'परिशुद्धता': 11,
#    'कैलेंडरमॉडल': 'http://www.wikidata.org/entity/Q1985727'},
#   {'समय': '+1946-07-03T00:00:00Z',
#    'समयक्षेत्र': 0,
#    'पहले': 0,
#    'बाद': 0,
#    'परिशुद्धता': 11,
#    'कैलेंडरमॉडल': 'http://www.wikidata.org/entity/Q1985727'}],
#  'फिल्म संपादक': ['रॉबर्ट वार'],
#  'शैली': ['ड्रामा फिल्म', 'कथा फिल्म', 'फ्लैशबैक फिल्म', 'जीवनी फिल्म'],
#  'मूल देश': ['संयुक्त राज्य अमेरिका'],
#  'फिल्म या टीवी शो की मूल भाषा': ['अंग्रेज़ी'],
#  'ऑलमूवी मूवी आईडी': ['v9737'],
#  'पुरस्कार प्राप्त': ['राष्ट्रीय फिल्म रजिस्ट्री',
#   'सर्वश्रेष्ठ लेखन, मूल पटकथा के लिए अकादमी पुरस्कार'],
#  'फिल्मांकन स्थान': ['सैन डिएगो', 'मालिबु'],
#  'पोर्ट फिल्म आईडी': ['109'],
#  'विषय की मुख्य श्रेणी': ['श्रेणी:नागरिक केन'],
#  'मूवीमीटर फिल्म आईडी': ['181'],
#  'डीएनएफ फिल्म आईडी': ['4156'],
#  'स्वीडिश फिल्म डाटाबेस फिल्म आईडी': ['8882'],
#  'एलोन्ट मूवी आईडी': ['106046'],
#  'कॉमन्स गैलरी': ['नागरिक केन'],
#  'शीर्षक': [{'विषय वस्तु': 'नागरिक केन', 'भाषा': 'एन'}],
#  'संगीतकार': ['बर्नार्ड हेरमान'],
#  'के लिए मनोनीत': ['सर्वश्रेष्ठ अभिनेता के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ निदेशक के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ सिनेमेटोग्राफी, ब्लैक एंड व्हाइट के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ फिल्म संपादन के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ लेखन, मूल पटकथा के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ चित्र के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ कला दिशा, काले और सफेद के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ मूल नाटकीय स्कोर के लिए अकादमी पुरस्कार',
#   'सर्वश्रेष्ठ ध्वनि मिश्रण के लिए अकादमी पुरस्कार'],
#  'रंग': ['काले और सफेद'],
#  'ČSFD फिल्म आईडी': ['9611'],
#  'ऑलसिनेमा फिल्म आईडी': ['10183'],
#  'नेटफ्लिक्स आईडी': ['60000605'],
#  'प्रोडक्शन डिजाइनर': ['वैन नेस्ट पोल्ग्लास'],
#  'किनोपोस्क फिल्म आईडी': ['331'],
#  'TCM मूवी डाटाबेस फिल्म आईडी': ['89'],
#  'फिल्मिरोडा रेटिंग': ['श्रेणी द्वितीय'],
#  'अवधि': [{'राशि': '+119', 'इकाई': 'http://www.wikidata.org/entity/Q7727'}],
#  'KINENOTE फिल्म आईडी': ['4147'],
#  'द्वारा वितरित': ['RKO पिक्चर्स'],
#  'पहली पंक्ति': [{'विषय वस्तु': 'रोजबड...', 'भाषा': 'एन'}],
#  'एलडीआईएफ आईडी': ['22517'],
#  'एलसिनेमा फिल्म आईडी': ['2009336'],
#  'ईडीबी फिल्म आईडी': ['t0001493'],
#  'एल्फिल्म फिल्म आईडी': ['33403'],
#  'Scope.dk फिल्म आईडी': ['1692'],
#  'Sratim आईडी': ['टीटी12957'],
#  'cine.gr फिल्म आईडी': ['579'],
#  'ओएफडीबी आईडी': ['2500'],
#  'ओपन मीडिया डाटाबेस फिल्म आईडी': ['15'],
#  'एफएसके फिल्म रेटिंग': ['एफएसके 12'],
#  'सीएनसी फिल्म रेटिंग (रोमानिया)': ['A.G.'],
#  'कॉस्ट्यूम डिजाइनर': ['एडवर्ड स्टीवेंसन'],
#  'फीचर फिल्मों आईडी की AFI सूची': ['27624'],
#  'कार्यकारी निर्माता': ['जॉर्ज शेफर'],
#  'Quora विषय आईडी': ['नागरिक-केन-१९४१-फिल्म'],
#  'TV.com आईडी': ['फिल्में/नागरिक-केन'],
#  'ईडर पहचानकर्ता': ['10.5240/BC23-A1B4-5875-7A94-303F-P'],
#  'सिने-रेसोर्स फिल्म आईडी': ['45143'],
#  'Cinema.de आईडी': ['1341618'],
#  'Isan': ['0000-0001-2C52-0000-P-0000-0000-0'],
#  'फिल्म वॉकर फिल्म आईडी': ['एमवी4139'],
#  'सिनेप्लेक्स फिल्म आईडी': ['190102'],
#  'नंबर मूवी आईडी': ['सिटीजन-केन'],
#  'मेटाक्रिटिक आईडी': ['फिल्म/नागरिक-केन-१९४१'],
#  'टीवी गाइड शो आईडी': ['110934'],
#  'ड्यूश सिंक्रोनकर्टी फिल्म आईडी': ['563'],
#  'शोषण वीजा संख्या': ['4521'],
#  'बीएफआई नेशनल आर्काइव वर्क आईडी': ['150026297'],
#  'बॉक्स ऑफिस मोजो फिल्म आईडी': ['नागरिककेन'],
#  'लागत': [{'राशि': '+839727', 'इकाई': 'http://www.wikidata.org/entity/Q4917'}],
#  'सिनेमेथेक क्यूबकोइस वर्क आइडेंटिजर': ['546'],
#  'विश्वकोश ब्रिटानिका ऑनलाइन आईडी': ['विषय/नागरिक-केन'],
#  'समीक्षा स्कोर': ['8.4/10'],
#  'गुणवत्ता है': ['Bechdel टेस्ट विफल रहता है'],
#  'Bechdel टेस्ट मूवी सूची आईडी': ['1266'],
#  'सिनेमेटोग्राफो फिल्म आईडी': ['2579'],
#  'विश्वकोश यूनिवर्सलिस आईडी': ['नागरिक-केन-ओ-वेले-एन-ब्रेफ', 'नागरिक-केन'],
#  'Filmweb.pl फिल्म आईडी': ['31279'],
#  'TMDb मूवी आईडी': ['15'],
#  'यूआरएल पर वर्णित': ['http://www.movist.com/movist3d/movie.asp?mid=122',
#   'https://www.newyorker.com/magazine/1971/02/20/raising-kane-i'],
#  'Moviepilot.de फिल्म आईडी': ['नागरिक-केन'],
#  'सिनेमागिया फिल्म आईडी': ['3919'],
#  'LUMIERE फिल्म आईडी': ['1337'],
#  'बीएफआई फिल्म्स, टीवी और लोगआईडी': ['4ce2b6a7a801b'],
#  'चश्मे आईडी': ['194618'],
#  'फिल्में कहीं भी आईडी': ['नागरिक-केन'],
#  'IdRef आईडी': ['085793779'],
#  'बिब्लिओथेक नेशनल डी फ्रांस आईडी': ['121560708'],
#  'VIAF आईडी': ['316753485'],
#  'अकादमी पुरस्कार डाटाबेस फिल्म आईडी': ['1389'],
#  'वीडियो': ['नागरिक केन ट्रेलर (1940). वेबम'],
#  'लेटबॉक्स्ड फिल्म आईडी': ['नागरिक-केन'],
#  'AMPAS संग्रह फिल्म आईडी': ['1000965'],
#  'इज़राइल आईडी के राष्ट्रीय पुस्तकालय': ['000624258'],
#  'गूगल प्ले मूवीज और टीवी आईडी': ['q2lto4sisZE'],
#  'Dove.org काम आईडी': ['68'],
#  'स्टोर नॉर्स्के लेसिकॉन आईडी': ['Citizen_Kane'],
#  'सीएनसी फिल्म रेटिंग (फ्रांस)': ['कोई उम्र प्रतिबंध नहीं (यू)'],
#  'कैंटिक आईडी': ['a2092447'],
#  'बिब्लिओटेका नैसिनल डी एस्पान आईडी': ['XX3821686'],
#  'कांग्रेस प्राधिकरण आईडी की लाइब्रेरी': ['n50051145'],
#  'नोआरएएफ आईडी': ['90684861'],
#  'FandangoNow आईडी': ['1MV361d5f9020da46a48ed6387429c22696']}

# %%
labelled_monuments['Q24815']
# Out:
# {'director': ['Orson Welles'],
#  'IMDb ID': ['tt0033467'],
#  'Commons category': ['Citizen Kane (1941 film)'],
#  'screenwriter': ['Orson Welles', 'Herman J. Mankiewicz', 'John Houseman'],
#  'cast member': ['Orson Welles',
#   'Joseph Cotten',
#   'Ruth Warrick',
#   'Everett Sloane',
#   'William Alland',
#   'Paul Stewart',
#   'George Coulouris',
#   'Dorothy Comingore',
#   'Agnes Moorehead',
#   'Ray Collins',
#   'Fortunio Bonanova',
#   'Erskine Sanford',
#   'Gus Schilling',
#   'Alan Ladd',
#   'Charles Bennett',
#   'Gino Corrado',
#   'Harry Shannon',
#   'Sonny Bupp',
#   'Walter Sande',
#   'Philip Van Zandt',
#   'Roland Winters'],
#  'director of photography': ['Gregg Toland'],
#  'production company': ['RKO Pictures'],
#  'instance of': ['film'],
#  'FilmAffinity ID': ['615891'],
#  'producer': ['Orson Welles', 'George Schaefer'],
#  'narrative location': ['New York City', 'Florida'],
#  'GND ID': ['4208625-5'],
#  'official website': ['http://www2.warnerbros.com/citizenkane/'],
#  'Freebase ID': ['/m/01lsl'],
#  'image': ['Citizen Kane poster, 1941 (Style B, unrestored).jpg',
#   'Citizen Kane poster, 1941 (Style A).jpg'],
#  'AlloCiné film ID': ['857'],
#  'Rotten Tomatoes ID': ['m/citizen_kane'],
#  'publication date': [{'time': '+1941-05-01T00:00:00Z',
#    'timezone': 0,
#    'before': 0,
#    'after': 0,
#    'precision': 11,
#    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#   {'time': '+1946-07-03T00:00:00Z',
#    'timezone': 0,
#    'before': 0,
#    'after': 0,
#    'precision': 11,
#    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'}],
#  'film editor': ['Robert Wise'],
#  'genre': ['drama film',
#   'fiction film',
#   'flashback film',
#   'biographical film'],
#  'country of origin': ['United States of America'],
#  'original language of film or TV show': ['English'],
#  'AllMovie movie ID': ['v9737'],
#  'award received': ['National Film Registry',
#   'Academy Award for Best Writing, Original Screenplay'],
#  'filming location': ['San Diego', 'Malibu'],
#  'PORT film ID': ['109'],
#  "topic's main category": ['Category:Citizen Kane'],
#  'MovieMeter film ID': ['181'],
#  'DNF film ID': ['4156'],
#  'Swedish Film Database film ID': ['8882'],
#  'Elonet movie ID': ['106046'],
#  'Commons gallery': ['Citizen Kane'],
#  'title': [{'text': 'Citizen Kane', 'language': 'en'}],
#  'composer': ['Bernard Herrmann'],
#  'nominated for': ['Academy Award for Best Actor',
#   'Academy Award for Best Director',
#   'Academy Award for Best Cinematography, Black-and-White',
#   'Academy Award for Best Film Editing',
#   'Academy Award for Best Writing, Original Screenplay',
#   'Academy Award for Best Picture',
#   'Academy Award for Best Art Direction, Black and White',
#   'Academy Award for Best Original Dramatic Score',
#   'Academy Award for Best Sound Mixing'],
#  'color': ['black-and-white'],
#  'ČSFD film ID': ['9611'],
#  'Allcinema film ID': ['10183'],
#  'Netflix ID': ['60000605'],
#  'production designer': ['Van Nest Polglase'],
#  'Kinopoisk film ID': ['331'],
#  'TCM Movie Database film ID': ['89'],
#  'Filmiroda rating': ['Category II'],
#  'duration': [{'amount': '+119',
#    'unit': 'http://www.wikidata.org/entity/Q7727'}],
#  'KINENOTE film ID': ['4147'],
#  'distributed by': ['RKO Pictures'],
#  'first line': [{'text': 'Rosebud...', 'language': 'en'}],
#  'LdiF ID': ['22517'],
#  'elCinema film ID': ['2009336'],
#  'EDb film ID': ['t0001493'],
#  'elFilm film ID': ['33403'],
#  'Scope.dk film ID': ['1692'],
#  'Sratim ID': ['tt12957'],
#  'cine.gr film ID': ['579'],
#  'OFDb ID': ['2500'],
#  'Open Media Database film ID': ['15'],
#  'FSK film rating': ['FSK 12'],
#  'CNC film rating (Romania)': ['A.G.'],
#  'costume designer': ['Edward Stevenson'],
#  'AFI Catalog of Feature Films ID': ['27624'],
#  'executive producer': ['George Schaefer'],
#  'Quora topic ID': ['Citizen-Kane-1941-movie'],
#  'TV.com ID': ['movies/citizen-kane'],
#  'EIDR identifier': ['10.5240/BC23-A1B4-5875-7A94-303F-P'],
#  'Ciné-Ressources film ID': ['45143'],
#  'Cinema.de ID': ['1341618'],
#  'ISAN': ['0000-0001-2C52-0000-P-0000-0000-0'],
#  'Movie Walker film ID': ['mv4139'],
#  'Cineplex film ID': ['190102'],
#  'The Numbers movie ID': ['Citizen-Kane'],
#  'Metacritic ID': ['movie/citizen-kane-1941'],
#  'TV Guide show ID': ['110934'],
#  'Deutsche Synchronkartei film ID': ['563'],
#  'exploitation visa number': ['4521'],
#  'BFI National Archive work ID': ['150026297'],
#  'Box Office Mojo film ID': ['citizenkane'],
#  'cost': [{'amount': '+839727',
#    'unit': 'http://www.wikidata.org/entity/Q4917'}],
#  'Cinémathèque québécoise work identifier': ['546'],
#  'Encyclopædia Britannica Online ID': ['topic/Citizen-Kane'],
#  'review score': ['8.4/10'],
#  'has quality': ['fails the Bechdel Test'],
#  'Bechdel Test Movie List ID': ['1266'],
#  'cinematografo film ID': ['2579'],
#  'Encyclopædia Universalis ID': ['citizen-kane-o-welles-en-bref',
#   'citizen-kane'],
#  'Filmweb.pl film ID': ['31279'],
#  'TMDb movie ID': ['15'],
#  'described at URL': ['http://www.movist.com/movist3d/movie.asp?mid=122',
#   'https://www.newyorker.com/magazine/1971/02/20/raising-kane-i'],
#  'Moviepilot.de film ID': ['citizen-kane'],
#  'CineMagia film ID': ['3919'],
#  'LUMIERE film ID': ['1337'],
#  'BFI Films, TV and people ID': ['4ce2b6a7a801b'],
#  'Prisma ID': ['194618'],
#  'Movies Anywhere ID': ['citizen-kane'],
#  'IdRef ID': ['085793779'],
#  'Bibliothèque nationale de France ID': ['121560708'],
#  'VIAF ID': ['316753485'],
#  'Academy Awards Database film ID': ['1389'],
#  'video': ['Citizen Kane Trailer (1940).webm'],
#  'Letterboxd film ID': ['citizen-kane'],
#  'AMPAS collections film ID': ['1000965'],
#  'National Library of Israel ID': ['000624258'],
#  'Google Play Movies & TV ID': ['q2LTo4SIsZE'],
#  'Dove.org work ID': ['68'],
#  'Store norske leksikon ID': ['Citizen_Kane'],
#  'CNC film rating (France)': ['no age restriction (U)'],
#  'CANTIC ID': ['a12092447'],
#  'Biblioteca Nacional de España ID': ['XX3821686'],
#  'Library of Congress authority ID': ['n50051145'],
#  'NORAF ID': ['90684861'],
#  'FandangoNow ID': ['1MV361d5f9020da46a48ed6387429c22696']}

# %%
with open('../Data/Films/Films_Hindi_Wikidata_Hi_Labelled/films_hi_labelled.json', 'w') as f:
    json.dump(hi_labelled_monuments, f)
